# %% [markdown]
# # Data Analysis Basics
# - Learning to use pandas and numpy to analyze past data from the lab

# %% [markdown]
# ### Import necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data

# %%
#Importing Data
raw = pd.read_csv(r"C:\Users\unlim\OneDrive\Documents\University of Washington\Summer_Teddy\OL_lang_learn\data\uclimb_OLCTS_data_080719.csv")

#Creating Excel file for the data
writer = pd.ExcelWriter('OLCTS_Excel.xlsx')
raw.to_excel(writer, index=False)
writer.save()

#Printing
df1 = pd.read_excel('OLCTS_Excel.xlsx')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)
print(df1)
# Out:
#     subject  Python_subject_ID   Age Gender     Notes  \
# 0   28210.0                NaN  24.0      M    No MRI
# 1   28211.0                NaN  20.0      M       NaN
# 2   28212.0            29212.0  28.0      F       NaN
# 3   28213.0                NaN   NaN    NaN  Drop-out
# 4   28214.0                NaN   NaN    NaN  Drop-out
# ..      ...                ...   ...    ...       ...
# 71      NaN            28325.0  19.0      M       NaN
# 72      NaN            28327.0  20.0      F       NaN
# 73      NaN            28329.0  22.0      M       NaN
# 74      NaN            28330.0  20.0      F       NaN
# 75      NaN            28331.0  20.0      F       NaN
#
#    Closed_EEGNotes_VisualInspect_OLCTS Open_EEGNotes_VisualInspect_OLCTS  \
# 0                                  NaN                    F4, O1 removed
# 1                                  NaN                        T7 removed
# 2                                  NaN                        T7 removed
# ...

# %% [markdown]
# #Descriptive Stats

# %%
columns1 = ["Age", "Slope_OLCTS", "LESSON_CorrSpeech_OLCTS", "LESSON_SpeechAttempts_OLCTS", "QUIZ_ ACC_StDev_OLCTS", "DIALOG_SpeechAttempts_OLCTS", "DIALOG_Score_OLCTS"]

list1 = []
for i in columns1:
    list1.append(np.mean(df1[i]))
    
list2 = []
for i in columns1:
  list2.append(np.median(df2[i]))
            
            
df2 = pd.DataFrame([(list1), (list2)], columns = columns1, index = ['Mean', 'Median'])
print(df2)
# Out:
#               Age  Slope_OLCTS  LESSON_CorrSpeech_OLCTS  \
# Mean    21.056338     1.001982               297.723404
# Median        NaN          NaN                      NaN
#
#         LESSON_SpeechAttempts_OLCTS  QUIZ_ ACC_StDev_OLCTS  \
# Mean                    1059.787234              14.025623
# Median                          NaN                    NaN
#
#         DIALOG_SpeechAttempts_OLCTS  DIALOG_Score_OLCTS
# Mean                      23.489362          594.042553
# Median                          NaN                 NaN

# %%
np.mean(df1["Age"])
np.median(df1["Age"])
np.std(df1["Age"])
# Out:
# 3.5080885367264614

# %%
# Out:
# nan
